# %%
# !pip install -U pip transformers
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.2)
# Collecting transformers
#   Downloading transformers-4.57.0-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 22.9 MB/s eta 0:00:00
# Downloading transformers-4.57.0-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 28.8 MB/s eta 0:00:00
# Installing collected packages: pip, transformers
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.2
#     Uninstalling transformers-4.56.2:
#       Successfully uninstalled transformers-4.56.2
# Successfully installed pip-25.2 transformers-4.57.0

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
checkpoint = 'facebook/nllb-200-distilled-600M'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]

# %%
print(f"{len(tokenizer.vocab)}\n")

tokenizer.vocab
# Out:
# 256204
# {'erci': 42029,
#  '▁osigura': 171595,
#  '▁ziyar': 65954,
#  '▁आगामी': 172881,
#  '▁деңге': 51850,
#  '▁näe': 130920,
#  '▁12:5': 209194,
#  '定め': 94876,
#  '▁starts': 186315,
#  'endhe': 141148,
#  '▁pamberi': 115047,
#  '▁uretse': 229852,
#  '▁Можеш': 160093,
#  '▁Tempat': 162889,
#  'પતિ': 194918,
#  '▁ತೆಗೆ': 40499,
#  '▁lengolo': 205806,
#  '▁воли': 131420,
#  '▁nsow': 230447,
#  'Hal': 240067,
#  '▁булачак': 76351,
#  '▁불신': 106807,
#  '▁uzat': 131823,
#  'ایم': 126217,
#  '!!!': 10660,
#  '▁بدا': 128896,
#  'ناش': 185229,
#  '▁Mass': 90953,
#  '▁ек': 25877,
#  '▁vysi': 192565,
#  '錬': 255196,
#  'נגען': 101442,
#  '▁دیدار': 181219,
#  'philayo': 192276,
#  '▁بير': 166038,
#  '24': 14412,
#  '▁Гайсәнең': 106079,
#  'صلہ': 62358,
#  '▁høyt': 143070,
#  '▁Ngwa': 106415,
#  '▁Lju': 204061,
#  'akhristu': 121118,
#  '▁Hier': 39385,
#  '▁തല': 93852,
#  '▁garantizar': 145071,
#  '▁જગ્યા': 101009,
#  '▁Singh': 212309,
#  '▁salon': 94247,
#  '▁ensimmäisen': 123908,
#  'nac': 192631,
#  '▁loyo': 156577,
#  '▁sokesa': 231154,
#  '▁Wéi': 36917,
#  '▁edwɛkɛ': 146672,
#  '▁Babban': 154481,
#  '▁पहचान': 74562,
#  'caksınız': 149612,
#  'ppui': 230071,
#  '▁bilgiler': 204032,
#  '▁हमरे': 63974,
#  '▁pale': 27161,
#  'monių': 31736,
#  '▁umntu': 36634,
#  'ારો': 24909,
#  'ອາກາດ': 240789,
#  'ካዮ': 201550,
#  '▁tuhle': 228196,
#  '▁høv': 60739,
#  'indre': 65495,
#  '▁irrit': 105694,
#  '▁bleiben': 117256,
#  '▁言い': 180975,
#  'sɔɔlaa': 186788,
#  '辅': 254811,
#  '▁экинчи': 181676,
#  '▁ओढ़': 233302,
#  '▁zamestnancov': 214179,
#  '▁тисячі': 237148,
#  'niż': 159666,
#  '▁تىرى': 77255,
#  'Sav': 116720,
#  '▁kuwerenga': 242894,
#  '▁Теперь': 116571,
#  '▁awdurdod': 218001,
#  '▁төлөв': 136994,
#  'ལ་ལུ་ཅིག་': 178445,
#  '▁teis': 15990,
#  '▁زیند': 83644,
#  'ಬೇಕ': 11478,
#  '▁سەی': 61427,
#  'ến': 2929,
#  '▁shoko': 143081,
#  '▁നിന്റെ': 66844,
#  '▁ଜାଣ': 27937,
#  'ọi': 21785,
#  '▁дәвам': 84648,
#  '▁adulto': 201024,
#  '網路': 94079,
#  '▁kwetfu': 150791,
#  'caba': 242930,
#  '이었습니다': 65706,
#  'kileyo': 32026,
#  '▁pagtut': 213020,
#  '▁Lake': 56280,
#  '筹': 253556,
#  '▁xɔ': 15484,
#  'స్ప': 145835,
#  '▁ولري': 170913,
#  '▁dansa': 172962,
#  '▁tahe': 202755,
#  '结果': 142322,
#  '▁לינק': 186065,
#  'sur': 50001,
#  'daman': 118703,
#  'ngre': 205335,
#  '▁ebukwini': 238849,
#  '्यां': 49021,
#  '▁kebang': 151674,
#  'ക': 248316,
#  '▁패': 32130,
#  '▁twr': 236530,
#  '▁поговори': 78257,
#  'ambene': 205633,
#  'crú': 201066,
#  '▁байқа': 120564,
#  'ውን': 4471,
#  '▁био': 18822,
#  '▁ତାଲ': 223622,
#  '▁settim': 71488,
#  '▁Awa': 73205,
#  '▁5.000': 103181,
#  'cano': 101039,
#  '▁ကျမ': 182710,
#  '▁ongelmia': 209272,
#  'wom': 27371,
#  '▁শুনি': 99124,
#  '▁лау': 230077,
#  '▁сфера': 190069,
#  'σατε': 158857,
#  '▁itovo': 111251,
#  'pati': 25022,
#  'ラリア': 55007,
#  '▁escritor': 193066,
#  '▁وجہ': 53298,
#  'ফে': 175948,
#  '▁likumu': 223048,
#  'فه': 24842,
#  '▁Эта': 221515,
#  '▁paï': 57653,
#  '▁neni': 32292,
#  'ڪا': 67288,
#  'བསྒྱ': 84130,
#  '▁құрылым': 110683,
#  '▁nisbatan': 98807,
#  '▁kwizi': 169693,
#  '魔術': 185226,
#  '▁scríobh': 148954,
#  'шься': 118226,
#  '▁gukora': 30553,
#  '▁Kabili': 70173,
#  'kohol': 125676,
#  '▁sèddi': 120072,
#  'نية': 89598,
#  'Can': 70291,
#  '▁након': 46644,
#  '▁fahefana': 213185,
#  '▁darbuotojų': 148633,
#  '▁અમેરિકા': 113063,
#  '▁길': 14495,
#  '▁ακό': 34453,
#  '▁Ṛ': 45059,
#  '▁راتلون': 161773,
#  '▁pitanju': 197841,
#  'クス': 115747,
#  '▁obsahuje': 135157,
#  '州の': 101847,
#  'ındır': 146772,
#  'bə': 18669,
#  '▁100.000': 84151,
#  '▁vraća': 247333,
#  '▁өзге': 54734,
#  'sahalo': 160300,
#  '▁նոր': 30808,
#  '▁айып': 164998,
#  '▁στοιχείο': 160402,
#  'jdete': 138996,
#  '▁iespēju': 87556,
#  '▁regional': 39893,
#  '▁көңүл': 61597,
#  'isali': 141040,
#  '▁Wiedz': 221289,
#  'हरू': 6264,
#  '▁દરરોજ': 212479,
#  '▁Finans': 173653,
#  'ಡುವ': 34528,
#  '▁kamachin': 191328,
#  '▁genes': 218072,
#  'mies': 98159,
#  'وونە': 128379,
#  '▁ប្រសិន': 74194,
#  '▁האב': 38720,
#  '▁ਚੰ': 51344,
#  '官方': 195680,
#  'ىشت': 66403,
#  '▁Lomb': 109070,
#  '▁afeg': 169148,
#  '▁konse': 49496,
#  'ⵢⵏ': 49936,
#  '▁tubu': 78693,
#  '▁επικ': 79183,
#  '▁tkopri': 214020,
#  '▁prijatelja': 131100,
#  '▁пор': 64059,
#  'າຍຸ': 86715,
#  '▁เท่า': 139680,
#  '▁মানসিক': 154018,
#  'omá': 242713,
#  '▁odnos': 71249,
#  '▁lana': 28577,
#  '母亲': 220764,
#  '▁berubah': 48845,
#  '▁Gül': 244646,
#  'hya': 127721,
#  '▁ஊழிய': 200162,
#  '▁wrote': 77425,
#  '▁દુનિયા': 118100,
#  '▁prati': 46045,
#  'abona': 113049,
#  '▁आरोपी': 193040,
#  '▁Oracle': 194233,
#  '▁wiwe': 64402,
#  '▁Itulah': 97037,
#  '▁ফ': 5145,
#  '蛮': 254843,
#  'éncia': 58102,
#  '▁malosi': 60360,
#  'ื่อ': 8866,
#  '▁Програ': 73351,
#  '▁علي': 10992,
#  'šwa': 14238,
#  '▁հիմն': 121427,
#  'čev': 206225,
#  '▁లు': 146991,
#  'ikah': 107117,
#  '駅': 253120,
#  'odadh': 86918,
#  '▁aang': 25120,
#  '▁certificate': 192197,
#  '▁19;': 117127,
#  '▁города': 88425,
#  '很': 251563,
#  'დით': 46756,
#  '▁சரியாக': 196465,
#  '्वल': 213361,
#  '그': 248435,
#  'ندا': 10257,
#  '▁ielā': 108133,
#  'tarë': 174605,
#  '▁abaningi': 62903,
#  '▁°': 21308,
#  '▁чувство': 129461,
#  '▁hlauh': 190833,
#  '▁waŋ': 213938,
#  '▁அமை': 36890,
#  'ौन': 62231,
#  'жний': 234141,
#  'కంటే': 61454,
#  '▁ochr': 77770,
#  'ူဝ်း': 77675,
#  '▁कानूनी': 161110,
#  '▁તકની': 241356,
#  'akhumbanga': 224521,
#  '▁priekšsēd': 105535,
#  '▁Gibe': 179632,
#  '▁neįmanoma': 229073,
#  '▁aspect': 65432,
#  '▁тауар': 57433,
#  '▁skoraj': 107029,
#  '▁Questi': 165258,
#  'ියේ': 33977,
#  '▁живуть': 237636,
#  '▁систем': 38839,
#  'šali': 110252,
#  '▁হাম': 164980,
#  '▁इलाज': 128335,
#  '▁Оста': 88595,
#  '▁dniu': 212294,
#  '▁производства': 190334,
#  '呼ばれる': 198224,
#  '▁omfatte': 192721,
#  'ჩნდა': 229124,
#  '▁gilt': 104458,
#  'ጤ': 251714,
#  '▁асыру': 39575,
#  '▁dočas': 178721,
#  '▁SP': 45053,
#  'بط': 67831,
#  'wekyo': 83515,
#  '▁jedhamu': 113504,
#  '▁pohyb': 205117,
#  'gt': 3239,
#  '▁40,000': 173068,
#  'zony': 187094,
#  '▁utvikling': 118661,
#  '▁kuchuluka': 155534,
#  'cadal': 191697,
#  '▁span': 132751,
#  '▁wòle': 45550,
#  '▁saddex': 141639,
#  'фил': 199776,
#  'ombanga': 217976,
#  'edih': 184413,
#  '▁ziman': 109112,
#  'okazi': 153387,
#  'ريز': 201810,
#  '▁ਫਿਲ': 92682,
#  '▁sidde': 241915,
#  '▁πλευ': 168761,
#  '▁მხ': 27485,
#  '▁結果': 104451,
#  '▁Eisen': 151154,
#  'opito': 165633,
#  '▁ಇನ್ನಷ್ಟು': 211794,
#  '▁እሞ': 52698,
#  '▁masewera': 91896,
#  '▁bolmak': 105274,
#  'ঔ': 253612,
#  '▁්': 94823,
#  'しなければならない': 52160,
#  '▁hoki': 13934,
#  '▁možeš': 68115,
#  'ግዚአብሄር': 186181,
#  'وشی': 82679,
#  '▁rigu': 47350,
#  '▁matamata': 175043,
#  '▁uygun': 96278,
#  '▁Fly': 88738,
#  'वाले': 124264,
#  '▁Jungtinių': 189579,
#  'nyoe': 177703,
#  '▁nweghị': 90109,
#  'angelwa': 197815,
#  '▁9:2': 33131,
#  '▁lǧ': 158202,
#  '▁někdo': 80986,
#  'ତିହା': 177900,
#  'allista': 143718,
#  '▁ajava': 206923,
#  '▁مانند': 19023,
#  'ኬ': 251619,
#  '▁fàs': 167079,
#  'ideach': 156592,
#  'uiesc': 226184,
#  'ism': 10716,
#  'elj': 133340,
#  '▁lilil': 70893,
#  '▁definitiv': 96305,
#  '▁мора': 16766,
#  '▁tabat': 79863,
#  '▁hovorí': 87970,
#  '▁regard': 46760,
#  '▁yokwenza': 207087,
#  'tiq': 80130,
#  '▁Ovitangi': 229541,
#  'onym': 117901,
#  '▁amyu': 41185,
#  'တာက': 26758,
#  'grup': 36093,
#  '▁liket': 86924,
#  '▁गैर': 66532,
#  '▁соціаль': 95405,
#  '▁先生': 237526,
#  'ங்': 80200,
#  '▁Gandhi': 134422,
#  '▁doğrudan': 176039,
#  'bhar': 94574,
#  'োধ': 26796,
#  '▁ինչպե՞ս': 160980,
#  '}},': 3840,
#  'mbɛ': 238719,
#  'jemy': 77006,
#  '▁30-40': 228188,
#  'let': 962,
#  '▁Moraš': 136386,
#  '▁lokasa': 186198,
#  '▁siyo': 129271,
#  '▁Sitten': 113929,
#  'цца': 1720,
#  '▁Pietų': 199823,
#  '▁också': 35134,
#  'chei': 81151,
#  '▁heula': 175366,
#  'nels': 196848,
#  '▁успіху': 219239,
#  '▁FIFA': 68978,
#  '▁zgr': 147453,
#  '▁bosakhut': 217246,
#  '▁venus': 239308,
#  '▁2002': 16034,
#  '▁Sra': 107982,
#  'ادم': 122057,
#  '럽': 250637,
#  '▁പതി': 136761,
#  '▁Pse': 98925,
#  '▁Amon': 122756,
#  'енән': 96264,
#  '▁wĩgiĩ': 199497,
#  '▁방법': 10879,
#  'прав': 9045,
#  '▁stair': 220995,
#  'ゲイ': 202068,
#  '▁Шуннан': 196006,
#  'ikho': 52325,
#  'ống': 5299,
#  '▁inkor': 133864,
#  'геҙ': 14980,
#  '▁(.': 178068,
#  '強調': 86840,
#  '▁omor': 127464,
#  '▁londekesa': 35884,
#  'पल': 129923,
#  '▁vir': 2178,
#  '▁зохион': 228223,
#  '▁అడుగు': 131484,
#  '実際': 19084,
#  '▁tũtonya': 61085,
#  '▁χαμη': 226936,
#  '▁random': 135808,
#  '▁finita': 170138,
#  '▁dụ': 6882,
#  '俺の': 182877,
#  '▁кешеләр': 13181,
#  'ăng': 6914,
#  '▁kwivwila': 123157,
#  '▁határoz': 186322,
#  '▁राज': 7708,
#  '▁iindaba': 179301,
#  '▁bilem': 142850,
#  '▁قیم': 24136,
#  '▁ትእዛዝ': 208973,
#  'язок': 212261,
#  '▁Moize': 82649,
#  '▁gipakita': 243451,
#  'qhele': 62873,
#  'ランド': 20269,
#  '▁هچ': 39021,
#  '▁Tady': 107205,
#  '▁સંગ્ર': 222615,
#  'zuva': 31487,
#  'vay': 67161,
#  'プログラムを': 213578,
#  'plɔ': 58131,
#  '▁cumpli': 186810,
#  'amue': 43639,
#  '▁congela': 246249,
#  '▁nofoaga': 62959,
#  '▁Δώ': 189482,
#  '▁کاتی': 55809,
#  '▁혼자': 57792,
#  'šatšing': 220242,
#  '▁хужа': 76418,
#  '▁gamay': 94440,
#  '▁бузург': 121033,
#  '▁botho': 71282,
#  'ekom': 14953,
#  '▁keess': 18147,
#  '▁imant': 231790,
#  '▁ክርስትያ': 100483,
#  '▁ම': 1376,
#  'rae': 24722,
#  '▁119:10': 175292,
#  '금을': 65396,
#  '▁talap': 139111,
#  '▁fheàrr': 49056,
#  '▁pisanan': 137511,
#  'ова': 59814,
#  '▁miejs': 47123,
#  '▁Qullan': 166430,
#  'ת': 248333,
#  'ìo': 125934,
#  '▁Themba': 210289,
#  'zul': 20695,
#  'ապես': 33402,
#  '▁European': 20511,
#  'Dani': 60841,
#  'ថា': 8014,
#  '▁분쟁': 187196,
#  '▁Contribu': 153428,
#  '큽': 254468,
#  'lules': 171388,
#  '▁Onun': 37442,
#  '瞬': 251936,
#  '▁ഇട': 56721,
#  '▁নিজেকে': 96447,
#  'vour': 113824,
#  '▁Studi': 45072,
#  '▁χαρακτή': 247379,
#  '▁ಹೀಗ': 185336,
#  '▁ezinye': 56751,
#  'essään': 191047,
#  'jar': 2686,
#  '▁Wĩ': 129832,
#  '▁orixinal': 132722,
#  '▁Airlines': 66101,
#  '▁vantshwa': 107451,
#  'ေၾကာင့္': 225410,
#  'рке': 28807,
#  'stal': 57805,
#  '▁Ан': 16933,
#  '配布': 205703,
#  '▁पढ़ने': 139275,
#  'ordine': 181837,
#  '▁اوباما': 196264,
#  '▁دیکھتے': 124296,
#  '▁نغ': 151262,
#  '▁Thing': 139802,
#  '▁پاس': 12459,
#  '▁sostit': 198917,
#  'ཞེས་པའི་': 228861,
#  '▁gebo': 125019,
#  '▁memasuki': 142528,
#  '▁säna': 73360,
#  'льному': 91601,
#  '▁Mahamanyang': 238872,
#  '▁קלי': 127256,
#  '▁ଶ୍ରମ': 203241,
#  '▁1:8,': 234494,
#  '▁ட்': 211967,
#  'umishi': 167189,
#  '▁iseng': 106174,
#  '▁Eða': 174053,
#  '使他们': 101194,
#  'пред': 77267,
#  'сного': 178700,
#  '▁তাক': 69838,
#  '▁mati': 11960,
#  '▁taps': 169155,
#  '宁': 254436,
#  '▁пара': 23655,
#  '▁кылырга': 222646,
#  '▁ལུ་གུ་': 184280,
#  '▁boppam': 201882,
#  'ูง': 227489,
#  '▁seenaa': 189177,
#  'egta': 185327,
#  'ሉ፡': 181252,
#  'бони': 230416,
#  'зија': 42597,
#  'veg': 26362,
#  '▁gom': 7717,
#  '▁Nime': 157908,
#  'Genesi': 176853,
#  '▁ظاہر': 85087,
#  '▁빠져': 103653,
#  '▁maitem': 204009,
#  '▁sadz': 97233,
#  'lud': 116196,
#  '▁maunten': 150725,
#  '▁jinkl': 108866,
#  '▁ഒപ്പം': 215149,
#  '▁عنوان': 12517,
#  'akozi': 101305,
#  '▁좋게': 213919,
#  '▁nødvendigt': 89014,
#  'gán': 231046,
#  '▁عرضه': 110069,
#  '▁determinar': 108254,
#  '▁दीन': 82001,
#  '▁baqa': 226339,
#  '▁owete': 105059,
#  'wh': 3055,
#  '▁swe': 59883,
#  'ग्रस्त': 213279,
#  '▁فرستاد': 193266,
#  '度は': 79176,
#  '▁nooc': 210134,
#  'ེད་': 2431,
#  '▁β': 5366,
#  'punk': 20008,
#  'ખ્ય': 64713,
#  '▁personali': 63211,
#  '▁belø': 247668,
#  '▁kahan': 229647,
#  '▁наголо': 195314,
#  'རྒོལ་': 107926,
#  '▁яр': 12197,
#  'ሊት': 133023,
#  '▁raised': 172636,
#  'matan': 35238,
#  '▁1,000': 42563,
#  '▁unterstüt': 138415,
#  '▁ehe': 139307,
#  '▁गइ': 49220,
#  '▁महसुस': 178922,
#  '▁Kristianon': 227028,
#  '▁۱۴': 192321,
#  '▁parlap': 141764,
#  '▁роден': 225891,
#  '▁nogen': 36172,
#  'imler': 148653,
#  '▁jade': 94890,
#  '▁नाही': 6550,
#  'ཡོད་པ་ཅིན་': 203289,
#  '▁svarte': 194885,
#  '▁ସେନା': 244873,
#  '▁humano': 80044,
#  '▁poľ': 136591,
#  '▁Adolf': 155763,
#  '▁ಜನರು': 58436,
#  'คอย': 232206,
#  '▁Mio': 85161,
#  '▁fucking': 96989,
#  '▁realiza': 95814,
#  '▁ನಾಶ': 217911,
#  'cció': 28707,
#  '▁inglise': 242306,
#  '▁mbʋ': 16897,
#  '以外に': 215761,
#  '▁tuntuu': 185599,
#  '歴史的な': 237883,
#  'zora': 171873,
#  '▁sessions': 245150,
#  '你要': 209428,
#  '▁መልሲ': 167934,
#  'persuni': 123186,
#  '▁wartawan': 207478,
#  '▁fogy': 89101,
#  'บรรดา': 70941,
#  '▁Seorang': 82545,
#  '▁မျက်နှာ': 177493,
#  '▁Harran': 193042,
#  'šwe': 24904,
#  '▁duran': 201134,
#  '▁sonder': 85822,
#  'baad': 132449,
#  '▁υπολογ': 151894,
#  '▁fip': 132306,
#  '▁kitos': 103798,
#  '▁Ekin': 211334,
#  'кте': 18910,
#  '▁mood': 55095,
#  'koo': 55786,
#  '▁silang': 53160,
#  'ڏھن': 47042,
#  '▁sofitu': 149809,
#  '▁3:16.': 95599,
#  'چې': 232369,
#  '▁vorm': 65795,
#  'ው።': 76162,
#  '▁rusange': 163464,
#  '▁föl': 26940,
#  'されません': 179086,
#  '▁юкка': 235850,
#  '▁sra': 77078,
#  '▁quelle': 57695,
#  '▁mabuk': 245251,
#  '▁ຊາ': 162836,
#  '▁алынып': 230677,
#  '▁سایر': 43667,
#  'ೆಗಳ': 78501,
#  'ull': 3090,
#  'рга': 3106,
#  '▁Status': 161764,
#  'ၢႆႈ': 136030,
#  'िती': 22853,
#  '▁kulank': 147545,
#  '▁lí': 5629,
#  'ската': 16763,
#  '▁erbyn': 64506,
#  'ಗಣ': 82461,
#  '▁prynu': 220993,
#  '▁awǐnnya': 234576,
#  'ທົ່ວ': 101424,
#  '▁ظاهر': 59591,
#  '▁waaqeff': 195540,
#  '▁krajinách': 154431,
#  'рію': 100518,
#  'lìn': 131495,
#  '..!': 88259,
#  '▁darurat': 191537,
#  '▁idane': 197554,
#  'বর্ত': 91861,
#  '恋': 252167,
#  '▁zatrud': 240346,
#  '記事は': 216838,
#  '▁féidir': 14819,
#  '권을': 77802,
#  '▁formação': 149288,
#  '▁گران': 93046,
#  '▁աղջիկ': 146506,
#  '▁koloba': 39223,
#  '▁준비': 24315,
#  '▁hlɔ': 107251,
#  '▁Robo': 204588,
#  '▁mababa': 175829,
#  '인들을': 178072,
#  '▁měs': 159148,
#  '▁marubu': 216787,
#  '大きな': 16539,
#  'ത്സ': 69873,
#  '▁suspend': 117999,
#  '▁бире': 18060,
#  '▁దగ్గర': 177571,
#  '▁అని': 16732,
#  'ствата': 122205,
#  '▁៦': 150741,
#  '▁Keď': 45114,
#  'skas': 208536,
#  'nr': 145201,
#  'nandzi': 190822,
#  'vino': 131450,
#  'ཉལ།': 55367,
#  'ຯ': 255899,
#  'bilisi': 190371,
#  '▁Apoi': 143871,
#  '▁various': 90147,
#  'latok': 100673,
#  '▁¡': 8886,
#  '▁アー': 213367,
#  '▁гі': 60795,
#  '▁umub': 69248,
#  'λω': 61847,
#  '▁azken': 111276,
#  'দিকে': 129668,
#  'alifornia': 28102,
#  'ച്ചി': 168253,
#  'አን': 129359,
#  '▁ընթացքում': 64293,
#  '一份': 218560,
#  '▁faigata': 112408,
#  '▁لیتے': 173719,
#  '▁λή': 195245,
#  '▁hið': 198858,
#  '▁Nde': 28095,
#  'ages': 25752,
#  'ཡེ་ཤུ་གི་': 198072,
#  'ၽၢႆႇ': 204566,
#  '▁senge': 86267,
#  'ването': 36565,
#  '▁ቱ': 195116,
#  'står': 37854,
#  '▁PowerPoint': 189783,
#  'ihi': 14787,
#  '▁hangarau': 143211,
#  '▁megad': 195294,
#  'енер': 183485,
#  'vo': 378,
#  '▁tulin': 204491,
#  'ሳል': 146631,
#  '▁sanc': 232788,
#  '積極的に': 155817,
#  'لائي': 185241,
#  'atich': 161450,
#  '▁جعل': 197990,
#  '▁européenne': 84655,
#  '▁ishonchli': 213889,
#  '▁sanāks': 222474,
#  'ẹkan': 185147,
#  '▁rahast': 128302,
#  '▁vav': 48932,
#  'быз': 6516,
#  'lembeze': 135499,
#  'wayisa': 183800,
#  '▁tierra': 82957,
#  'จะ': 4078,
#  '▁으로': 22809,
#  '▁ଜନ': 81076,
#  '▁tényleg': 120814,
#  '▁행복을': 170630,
#  '▁posiada': 240709,
#  'ığımı': 195725,
#  'adde': 11126,
#  '▁thöŋ': 141205,
#  '▁קרובות': 177853,
#  '▁بېرى': 20354,
#  '▁ਪੋਸਟ': 220534,
#  'ilm': 122640,
#  'အရာ': 58852,
#  '识': 251771,
#  '자로서': 226571,
#  'zivisa': 113606,
#  'ってもら': 156305,
#  'ario': 5663,
#  '▁ешқашан': 209677,
#  '▁რატომ': 47443,
#  '▁közvet': 221158,
#  'Nowa': 118608,
#  '▁kultúr': 163389,
#  '▁offshore': 235613,
#  '▁Sal': 7222,
#  '▁의미가': 149121,
#  '付けて': 237858,
#  'ക്ത': 38347,
#  'ٻ': 250051,
#  '▁बढ': 30011,
#  '▁mbala': 19584,
#  '▁Kumb': 123221,
#  '▁ʻ': 11646,
#  'ယူႇ': 43699,
#  'škem': 173966,
#  'kenkan': 159765,
#  'ologija': 241925,
#  'argi': 56648,
#  '▁रहे': 4755,
#  '嘞': 255237,
#  'ute': 4712,
#  'times': 81222,
#  '▁हृदय': 89992,
#  '▁你可以': 164526,
#  '▁Merkel': 133240,
#  '▁өмір': 58772,
#  '▁желтоқсандағы': 150801,
#  '▁Phoebe': 243032,
#  '▁ಸ್ವ': 25628,
#  '▁bambanag': 103885,
#  '▁тися': 160074,
#  '▁ਬਾਹਰ': 89483,
#  '▁besti': 28027,
#  '▁obvesti': 130714,
#  'Ban': 148028,
#  'を務': 143557,
#  '▁recentemente': 215337,
#  'ằ': 249615,
#  '▁poruš': 154678,
#  '▁myself': 55651,
#  '▁\'"': 66848,
#  'γος': 222364,
#  '▁말할': 47471,
#  '▁bulat': 245808,
#  '▁1:12)': 247314,
#  '▁spesso': 117078,
#  'hirwe': 146375,
#  '▁будівни': 197470,
#  'А': 248568,
#  '▁kende': 52998,
#  '▁мяр': 235668,
#  '\uf0b7': 254698,
#  '▁ehi': 100200,
#  '▁mekgwa': 98392,
#  'asid': 50320,
#  '▁មុខ': 109815,
#  '▁neta': 109465,
#  '▁Nelson': 83426,
#  '▁ɛha': 129370,
#  '▁arbeiði': 141823,
#  '▁attribu': 145825,
#  '▁Зат': 190669,
#  '▁예수의': 188083,
#  '▁oben': 166236,
#  '▁સ્વીકાર': 168315,
#  'èò': 62411,
#  '▁ఉన్నాను': 230523,
#  '▁fampiasana': 127717,
#  '▁nelle': 61539,
#  'နှံ': 232568,
#  '▁maintsy': 51712,
#  '▁አለው': 65572,
#  '▁Ked': 46684,
#  'ევა': 87479,
#  '▁dzī': 23793,
#  '▁चलो': 139368,
#  '▁yomwe': 36921,
#  'ַ': 248848,
#  '▁uscire': 161559,
#  'နည်း': 18417,
#  'скен': 61340,
#  '.[5': 103860,
#  '▁kiwa': 236382,
#  '▁غیره': 209087,
#  '6/': 28170,
#  'ugula': 214370,
#  '▁konference': 237500,
#  'көм': 108258,
#  '役に立つ': 220508,
#  '▁targ': 198336,
#  '▁mivu': 38129,
#  'leanna': 235208,
#  '▁Roberts': 106728,
#  'ဆက်': 46846,
#  '置': 250325,
#  'chhuah': 137618,
#  '▁प्राय': 92137,
#  '▁agyi': 155891,
#  '▁θες': 133125,
#  '▁wɛnsagun': 144738,
#  'ፊ': 250283,
#  '▁معی': 77336,
#  '又': 250622,
#  '▁bokhut': 143141,
#  '▁hangtod': 90739,
#  '▁beauty': 93675,
#  'ືອ': 45828,
#  '▁여호와께서': 145702,
#  '▁йәмәғәт': 213872,
#  '▁okol': 41248,
#  '▁Verwendung': 176044,
#  'Ս': 250494,
#  'పాటు': 106970,
#  '▁relat': 19606,
#  'メッセージを': 189075,
#  'ಟ': 248976,
#  '▁ಪ್ರವಾಸ': 199520,
#  '▁Matanitu': 125893,
#  'خصوص': 43627,
#  '▁thus': 45184,
#  '▁ireo': 6263,
#  'boljš': 219622,
#  '▁Talaga': 190719,
#  'ikutlo': 32942,
#  '▁ngay': 22527,
#  '▁juris': 62345,
#  'quip': 37470,
#  '恶魔': 223869,
#  'ர்க்': 234808,
#  '▁ធ្លាប់': 175571,
#  '▁fugir': 194327,
#  '▁ਪਾਰ': 85620,
#  '▁කොහෙ': 153932,
#  '▁Unions': 179471,
#  '▁yeelay': 86026,
#  'ચ્ચે': 59154,
#  '▁hneď': 171889,
#  '▁toepassing': 71977,
#  '▁gowy': 50865,
#  '▁spreag': 159642,
#  'ció': 2044,
#  '▁llamar': 162299,
#  '▁samling': 214753,
#  '飛行機': 99965,
#  '▁ପାରି': 180227,
#  '▁Ngaphandle': 153085,
#  '▁परिस्थिती': 120869,
#  '▁Noch': 183596,
#  'ırsız': 185657,
#  '▁qurilish': 164724,
#  '▁Ti': 2230,
#  '▁Qever': 221833,
#  '▁tôt': 212132,
#  'ሱን': 60137,
#  '▁تەش': 140809,
#  '▁muba': 116051,
#  'ennes': 27498,
#  '▁समाधान': 69359,
#  '▁اکنون': 61197,
#  '▁DH': 183476,
#  '▁tolino': 83739,
#  '▁리스트': 208019,
#  '▁несправед': 228737,
#  'omsnitt': 116707,
#  '▁bura': 47692,
#  'ႀကီး': 135521,
#  'ාවක්': 65197,
#  '▁faktor': 25950,
#  'დამ': 145281,
#  '▁ngwatanĩo': 69599,
#  '▁97%': 191688,
#  'īciju': 184606,
#  'bron': 147382,
#  'ipot': 225654,
#  '▁ପାକିସ୍ତାନ': 142475,
#  '▁haka': 10533,
#  'ৃতি': 50189,
#  '▁Casa': 42837,
#  '▁Tôi': 16090,
#  '澤': 255595,
#  '▁motha': 77707,
#  '▁upang': 12720,
#  'was': 2521,
#  'གཏན་': 119567,
#  'ታዊ': 28445,
#  '▁పార్టీ': 111317,
#  '▁eziningi': 59634,
#  '▁어른': 129762,
#  '▁түүх': 175804,
#  '르고': 77225,
#  '▁Масеҳ': 187449,
#  'నెట్': 212129,
#  '灼': 255837,
#  '▁ବ୍ଯ': 235333,
#  'dê': 212228,
#  '▁ਵਿਸ਼ੇਸ਼': 116860,
#  'тон': 17972,
#  '▁võttis': 197044,
#  'adda': 6534,
#  '편': 250234,
#  '▁gezicht': 217704,
#  'jalne': 232774,
#  'ELTS': 191784,
#  'isoko': 145455,
#  'atson': 101762,
#  '▁ńṣe': 94166,
#  '▁התא': 158417,
#  '▁nginya': 32856,
#  'өөд': 33524,
#  '▁kwesị': 189862,
#  '▁ഒരുപാട്': 186834,
#  'hariko': 246358,
#  '▁Atako': 70476,
#  '▁izandla': 213454,
#  'onnin': 243345,
#  ...}

# %%
thai_char_min = 0x0E00
thai_char_max = 0x0E7F

thai_tokens = [
    token for token in tokenizer.vocab.keys()
    if any(thai_char_min <= ord(char) <= thai_char_max for char in token)
]

thai_token_count = len(thai_tokens)
sample_size = 20
thai_tokens_sample = thai_tokens[:sample_size]


print(f"{thai_token_count}\n")
for token in thai_tokens_sample:
  print(token)
# Out:
# 1712
#
# โปร
# ความคิด
# มาร
# อยู่ที่
# ▁เกี่ยว
# รัฐ
# ได้ว่า
# ิล
# ▁เห
# ว่าเขา
# อม
# ทด
# เป็นคน
# ้อย
# กําลังจะ
# เคร
# เย็น
# แปลง
# ็ด
# มั้ย

# %%
import tensorflow as tf
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np
import math

# %%
sentence = 'Work hard, play harder'

# %%
cleaned_sentence = sentence.replace(',', '')
cleaned_sentence
# Out:
# 'Work hard play harder'

# %%
words = cleaned_sentence.split()
words
# Out:
# ['Work', 'hard', 'play', 'harder']

# %%
sorted_words = sorted(words)
sorted_words
# Out:
# ['Work', 'hard', 'harder', 'play']

# %%
dc = {word: index for index, word in enumerate(sorted_words)}
dc
# Out:
# {'Work': 0, 'hard': 1, 'harder': 2, 'play': 3}

# %%
sentence_int = tf.constant(
    [dc[s] for s in sentence.replace(',', '').split()],
    dtype=tf.int32
)

# %%
print(sentence)
print(sentence_int)
# Out:
# Work hard, play harder
# tf.Tensor([0 1 3 2], shape=(4,), dtype=int32)

# %%
# สร้าง embedding layer
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

embed = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)

# %%
embedded_sentence = embed(sentence_int)

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.04234311, -0.00708368],
#        [ 0.0026127 ,  0.04861036],
#        [ 0.00521044,  0.0060385 ],
#        [-0.0011544 , -0.02379712]], dtype=float32)>

# %%
tf.random.set_seed(123)
vocab_size = 50_000
embedding_dim = 2

dummy_input = tf.constant([0, 1, 2], dtype=tf.int32)

# Case 1 Default initializer (RandomUniform(-0.05, 0.05))
embed_default = tf.keras.layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim)
_ = embed_default(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_default = embed_default.get_weights()[0].flatten()
weights_default.shape
# Out:
# (100000,)

# %%
# Case 2 GlorotUniform initializer
tf.random.set_seed(123)
embed_glorot = tf.keras.layers.Embedding(
    input_dim=vocab_size,
    output_dim=embedding_dim,
    embeddings_initializer=tf.keras.initializers.GlorotUniform()
)
_ = embed_glorot(dummy_input) # เรียกใช้งาน layer เพื่อสร้าง weights
weights_glorot = embed_glorot.get_weights()[0].flatten()
weights_glorot.shape
# Out:
# (100000,)

# %%
fig = make_subplots(rows=1, cols=1)

fig.add_trace(go.Histogram(x=weights_default, nbinsx=50, name="Default Uniform [-0.05, 0.05]", opacity=0.6))
fig.add_trace(go.Histogram(x=weights_glorot, nbinsx=50, name="Glorot Uniform", opacity=0.6))

fig.update_layout(
    title_text='Embedding Layer Initialization Comparison',
    xaxis_title_text='Weight values',
    yaxis_title_text='Frequency',
    barmode='overlay',
    legend_orientation="h",
    legend_yanchor="bottom",
    legend_y=1.02,
    legend_xanchor="right",
    legend_x=1
)

fig.show()

print("Default initializer range ", weights_default.min(), weights_default.max())
print("Glorot initializer range ", weights_glorot.min(), weights_glorot.max())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="09e175c4-f52b-47f5-9e7c-4556f0f0efa8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09e175c4-f52b-47f5-9e7c-4556f0f0efa8")) {                    Plotly.newPlot(                        "09e175c4-f52b-47f5-9e7c-4556f0f0efa8",                        [{"name":"Default Uniform [-0.05, 0.05]","nbinsx":50,"opacity":0.6,"x":[0.0060621127,0.015765164,0.029897634,-0.03111831,-0.005767882,0.027148236,0.018493142,0.008495629,-0.025590766,0.040777873,-0.027259111,0.03049941,0.048751723,-0.019564008,0.012127578,0.025140215,-0.030355489,-0.0026254058,0.0030062571,0.038953032,-0.04094572,-0.017252006,-0.0027744286,-0.04937879,0.020710912,0.0017979965,-0.040201735,-0.0029807203,-0.04500847,-0.046632815,-0.046441425,-0.036596797,0.019548599,-0.03851644,-0.025205076,0.016972352,-0.026685966,-0.049755182,0.019386206,-0.0008019209,-0.007822514,0.03709444,0.0038299933,-0.0066105723,-0.002732098,-0.0010837913,-0.018872106,0.034186732,0.033906225,0.02488767,0.0060178526,-0.040788997,-0.0058173165,0.039776217,-0.022080278,-0.027581835,0.0016998053,0.049204838,-0.014134802,-0.00730915,0.046144094,-0.024919271,0.036979366,-0.013003528,-0.027900934,-0.009149086,-0.035500623,0.02239624,0.00828252,0.0066016316,0.010235477,-0.027028263,-0.03454224,-0.017445408,0.014414813,-0.042093314,0.010016907,-0.03804698,-0.036347806,0.031432737,-0.014459632,0.03285947,-0.038175356,-0.0050598606,-0.00866586,0.011807155,0.0073092356,0.009121835,-0.015633475,-0.038373947,0.047989797,-0.008767188,-0.008609794,0.024768423,0.031529773,-0.020475423,0.016016316,-0.020761205,-0.044230808,-0.00051072985,-0.046586264,-0.0008857958,-0.024568392,0.013384055,-0.020785619,-0.0179554,0.04466288,-0.00302881,0.02548853,-0.0480235,-0.014710166,-0.0042161457,-0.0055663697,0.00230968,-0.0030807145,0.03956249,-0.0022350773,-0.026002193,-0.026073014,0.016154114,-0.014746081,-0.025735557,0.04417287,-0.008368291,-0.022990609,0.009813823,0.047213588,-0.034186617,0.037039805,0.01857293,0.046748962,0.04217923,-0.044126343,0.023906697,0.024749126,-0.032499064,0.034650717,-0.02404654,-0.04078599,-0.0067574866,0.013606075,0.016162504,-0.012824595,-0.044240773,0.012468506,0.021712173,-0.03882606,-0.0143992305,0.0016823523,0.01467954,0.033973623,0.041212585,-0.031117762,0.04274838,-0.023660278,-0.015906751,-0.025900805,-0.03778231,0.021657314,0.01105075,0.017937485,0.03601757,0.03741813,-0.033755563,-0.013993822,0.016982999,0.00853195,0.04700147,0.038645137,0.02669252,0.0009598732,0.03941988,0.023487035,-0.045363974,-0.04176109,0.014271881,0.03468403,0.02493297,0.00011466816,0.04026163,-0.039639473,0.04968908,0.0087613575,-0.008505512,0.035952937,0.04537001,0.0075180307,-0.001004599,-0.037228893,-0.040637087,0.009304941,0.0049956664,-0.036319576,-0.04650637,0.0071310885,0.0150896795,0.011464678,-0.014158655,0.024694275,-0.044796374,0.024730567,-0.047445595,-0.009879567,-0.03849541,-0.031154979,-0.040872633,-0.026191402,0.024311256,0.004795801,0.040064517,0.02754451,-0.007011555,-0.04028977,-0.0117046945,-0.01787578,-0.011695363,0.035364773,-0.015902221,-0.03185316,-0.026733506,-0.017405558,-0.021627832,-0.012728799,-0.031071102,0.005541563,0.015631247,0.01685853,0.048697475,0.04097608,-0.04599775,-0.014159001,0.015056673,-0.0017456189,0.04053021,-0.017273594,-0.039573334,0.012810793,-0.015734483,-0.007981826,0.042642068,-0.03907001,-0.021638786,-0.004868351,0.021111522,-0.009519637,-0.014126897,0.037361685,-0.038283825,0.0075922385,-0.037953995,0.0118375905,0.013807002,-0.04883466,-0.02717395,-0.033869542,0.042074468,-0.01897247,-0.021743907,-0.024280464,-0.013364553,-0.03495114,0.00015548617,-0.007601846,-0.04416994,-0.049242735,0.010874283,-0.020535195,0.036411252,-0.0142691955,0.008569408 ...
# Default initializer range  -0.049997997 0.049999822
# Glorot initializer range  -0.01095417 0.010954133

# %%
def glorot_uniform_limits(fan_in, fan_out):
    limit = math.sqrt(6.0 / (fan_in + fan_out))
    a, b = -limit, limit
    return a, b

# ตัวอย่าง Embedding layer (vocab_size=50000, embedding_dim=2)
fan_in = 50000
fan_out = 2

a, b = glorot_uniform_limits(fan_in, fan_out)
print("Glorot Uniform a =", a)
print("Glorot Uniform b =", b)
# Out:
# Glorot Uniform a = -0.010954232067652772
# Glorot Uniform b = 0.010954232067652772

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
token_embedding_layer = model.model.encoder.embed_tokens
token_embedding_layer.weight.shape
# Out:
# torch.Size([256206, 1024])

# %%
long_sentence = "In the vast realm of natural language processing, understanding the nuances of how models handle sequential data is crucial. Positional encoding plays a vital role in providing this essential information to the model, allowing it to differentiate between words at different positions in a sentence, which is fundamental for tasks like translation, summarization, and text generation."

# %%
tokens = tokenizer(long_sentence, return_tensors="pt")

print(tokens['input_ids'][0])
# Out:
# tensor([256047,    717,    349,  14430,  12284, 248070,    452,  25307,  65445,
#         157278, 248079, 133930,    349,    713,  75831,    452,  11657, 141057,
#          47274, 116914, 124785,   6067,    248, 182071, 248075,  12013,  58409,
#          12025, 246156,   3054,    705,      9, 104781,  76065,    108, 174693,
#           3423, 140515,  18781,    202,    349,  14916, 248079,  82935,     87,
#            796,    202,  53054,    502,  25914,  51744,    230,  30158, 199073,
#            108,      9, 109267, 248079,   9089,    248,  75529,    351, 226047,
#           6399, 200356, 248079,   2493, 109207, 181953, 248079,    540,  35883,
#         120531, 248075,      2])

# %%
len(tokens['input_ids'][0])
# Out:
# 75

# %%
token_embedding_layer(tokens['input_ids'][0][0]).shape
# Out:
# torch.Size([1024])

# %%
token_embeddings = token_embedding_layer(tokens['input_ids'][0])

print("Token Embedding Matrix shape", token_embeddings.shape)
token_embeddings
# Out:
# Token Embedding Matrix shape torch.Size([75, 1024])
# tensor([[-5.0000e+00, -1.2725e+00, -9.3604e-01,  ..., -1.8297e+01,
#          -9.1328e+00, -1.0672e+01],
#         [ 2.6416e-01,  2.6831e-01,  2.0117e-01,  ...,  3.2715e+00,
#          -3.2402e+00,  3.1738e+00],
#         [ 4.3579e-01, -2.3352e-01,  2.6825e-02,  ...,  5.4648e+00,
#           2.7129e+00,  5.5430e+00],
#         ...,
#         [ 8.5859e+00, -4.5391e+00, -4.7314e-01,  ..., -7.9529e-02,
#           7.4844e+00, -7.5156e+00],
#         [-2.4863e+00, -2.7515e-01,  5.6114e-03,  ...,  1.0180e+01,
#          -7.2422e+00, -4.8047e+00],
#         [-7.8320e-01, -9.0527e-01, -9.4482e-01,  ...,  3.1078e+01,
#          -8.1494e-01, -8.7354e-01]], grad_fn=<MulBackward0>)

# %%
import plotly.express as px

token_embeddings_np = token_embeddings.detach().numpy()

fig = px.imshow(
    token_embeddings_np,
    color_continuous_scale="RdBu",
    labels=dict(x="Embedding Dimension", y="Token Index", color="Value"),
    title="Token Embedding Heatmap"
)

fig.update_xaxes(side="top")
fig.update_layout(height=500, width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="599febce-5421-4ddf-91db-30dd47b80a46" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("599febce-5421-4ddf-91db-30dd47b80a46")) {                    Plotly.newPlot(                        "599febce-5421-4ddf-91db-30dd47b80a46",                        [{"coloraxis":"coloraxis","name":"0","z":[[-5.0,-1.2724609,-0.93603516,-0.83203125,-2.8164062,-1.4824219,-1.4541016,-1.5322266,-2.0976562,-1.3632812,-1.3916016,-0.8466797,-0.40673828,-2.1171875,-2.9785156,-5.9257812,-3.2480469,-3.2265625,-5.4296875,-4.6445312,-4.6210938,-2.7578125,1.6699219,0.23669434,2.6699219,0.6894531,2.1640625,-1.4003906,-1.5332031,1.078125,0.27319336,-0.044677734,-4.484375,2.7148438,-0.82714844,-0.9248047,-1.4833984,1.5966797,0.3942871,2.7675781,-0.18151855,-1.4208984,1.4765625,-3.5234375,-1.9033203,-0.36523438,-3.0449219,-7.0078125,3.3378906,-2.4453125,-1.21875,0.6464844,-0.20788574,0.50927734,-0.35546875,2.6171875,-1.484375,-7.21875,-1.6210938,-4.1679688,-6.3476562,0.6245117,-0.8540039,-0.36621094,0.53759766,-4.03125,-1.4160156,-1.6035156,-0.20056152,-2.6367188,0.5800781,-4.2421875,-1.0517578,1.6572266,-3.7011719,-2.1425781,-2.3203125,-0.46142578,-3.1484375,-3.5039062,5.1484375,1.5410156,-2.4667969,1.8359375,-0.8930664,1.2636719,-2.5976562,1.8720703,-1.9160156,1.6894531,-0.9248047,-3.6503906,-2.6464844,3.9433594,-1.8027344,0.08276367,-2.3632812,-0.3720703,-1.2607422,-1.0986328,0.82666016,-2.9101562,-0.7949219,3.4023438,3.4804688,-5.0664062,1.2001953,-2.8222656,-0.0925293,-0.06573486,-4.15625,-0.24804688,-5.2421875,-5.2070312,-1.1210938,-2.1269531,-0.9296875,1.3291016,0.5756836,3.2910156,0.028930664,-3.2949219,-0.74902344,1.9746094,3.2324219,-2.9824219,-4.078125,2.9355469,-0.37890625,-6.0429688,-1.1982422,5.2929688,-0.9555664,-1.0087891,-2.4609375,-2.8320312,7.0390625,1.34375,6.0195312,-4.3007812,-0.33691406,1.3554688,1.9746094,0.88964844,-0.8432617,-1.1689453,2.0429688,-3.375,-2.2167969,-1.0732422,-6.8984375,5.59375,0.70751953,-2.4511719,1.0996094,2.953125,1.5742188,0.7495117,-4.53125,-2.7207031,2.3007812,0.19958496,1.5048828,-2.625,4.9140625,1.2363281,-1.4033203,-0.7739258,2.9023438,-1.9794922,0.5097656,-5.03125,4.3164062,-1.4628906,-3.6289062,7.9023438,-5.4101562,-0.79541016,1.2724609,-3.03125,-3.2617188,-0.7285156,9.453125,6.8710938,-0.78027344,0.8461914,-0.028656006,-1.4453125,-0.89697266,0.20361328,-5.5234375,-3.1992188,0.09460449,5.4921875,-2.9335938,5.6484375,0.92285156,2.1542969,-3.6738281,-2.5722656,-5.1953125,-4.4296875,6.0625,2.1171875,-0.19140625,2.3886719,-2.3144531,-1.4082031,1.1728516,9.0859375,-5.3789062,-0.14526367,-3.1972656,1.8076172,0.8041992,2.4199219,-0.009849548,-6.2070312,-1.6171875,-3.8027344,2.0898438,-2.5351562,0.86816406,0.17224121,-0.5800781,3.7070312,1.9980469,5.015625,-1.7001953,-0.2734375,-1.4921875,3.2675781,-1.4570312,-3.8964844,-1.7021484,-5.0351562,2.5410156,-4.4414062,-2.9394531,9.359375,-0.703125,-0.5439453,-11.515625,4.1367188,6.640625,2.7636719,-2.6054688,-0.5625,1.6259766,0.94140625,0.2746582,0.24401855,-5.3671875,4.6367188,-5.25,6.1484375,-5.5429688,-0.3149414,-2.1875,-2.0859375,-1.1806641,7.3671875,-0.17993164,-1.1494141,-15.9296875,-1.5449219,-3.7226562,-4.6484375,3.0507812,5.1835938,-2.4550781,3.71875,-0.9057617,8.40625,0.1361084,-4.65625,3.203125,0.28466797,-7.28125,-2.9941406,-5.0625,0.92578125,-12.6796875,-5.2929688,0.47802734,18.0625,-11.078125,3.34375,-3.3222656,0.3605957,-6.3164062,-17.1875,3.6796875,-4.4257812,-8.4375,-6.2578125,16.046875,-4.4570312,0.10467529,0.18127441,-4.0664062,-0.4375,1.3125,-1.5859375,-3.6503906,-5.1875,0.32910156,-3.6367188,-3.1835938,-1.5380859,-2.1601562,2.2910156,2.0507812,4.1367188,3.1503906,-0.33325195,-0.03668213,0.8671875,-2.8515625,-7.3359375,-2.9296875,-4.6015625,0.0 ...

# %%
d = embedded_sentence.shape[-1]
d
# Out:
# 2

# %%
d_q, d_k, d_v = 2, 2, 4

d_q, d_k, d_v
# Out:
# (2, 2, 4)

# %%
tf.random.set_seed(123)
W_query = tf.Variable(tf.random.uniform((d, d_q)), trainable=True)
W_key   = tf.Variable(tf.random.uniform((d, d_k)), trainable=True)
W_value = tf.Variable(tf.random.uniform((d, d_v)), trainable=True)

# %%
print(W_query.shape, W_key.shape, W_value.shape)
# Out:
# (2, 2) (2, 2) (2, 4)

# %%
W_query
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.12615311, 0.5727513 ],
#        [0.2993133 , 0.5461836 ]], dtype=float32)>

# %%
W_key
# Out:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0.88968754, 0.12354946],
#        [0.7718717 , 0.6850728 ]], dtype=float32)>

# %%
W_value
# Out:
# <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
# array([[0.48962688, 0.5857923 , 0.36451697, 0.6550509 ],
#        [0.9075084 , 0.37557673, 0.6882372 , 0.25384045]], dtype=float32)>

# %%
embedded_sentence
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.04234311, -0.00708368],
#        [ 0.0026127 ,  0.04861036],
#        [ 0.00521044,  0.0060385 ],
#        [-0.0011544 , -0.02379712]], dtype=float32)>

# %%
queries = tf.matmul(embedded_sentence, W_query)
keys    = tf.matmul(embedded_sentence, W_key)
values  = tf.matmul(embedded_sentence, W_value)

# %%
print("Queries shape", queries.shape)
queries
# Out:
# Queries shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.00322148,  0.02038308],
#        [ 0.01487933,  0.0280466 ],
#        [ 0.00246472,  0.00628241],
#        [-0.00726843, -0.01365878]], dtype=float32)>

# %%
print("Keys shape", keys.shape)
keys
# Out:
# Keys shape (4, 2)
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[ 0.03220444,  0.00037863],
#        [ 0.03984544,  0.03362443],
#        [ 0.00929661,  0.00478056],
#        [-0.01939538, -0.01644539]], dtype=float32)>

# %%
print("Values shape", values.shape)
values
# Out:
# Values shape (4, 4)
# <tf.Tensor: shape=(4, 4), dtype=float32, numpy=
# array([[ 0.01430383,  0.0221438 ,  0.01055953,  0.02593877],
#        [ 0.04539355,  0.01978742,  0.03440783,  0.01405072],
#        [ 0.00803116,  0.00532015,  0.00605521,  0.00494592],
#        [-0.02216131, -0.00961388, -0.01679886, -0.00679686]],
#       dtype=float32)>

# %%
omega = tf.matmul(queries, keys, transpose_b=True)

print("Omega shape", omega.shape)
print("Omega (Unnormalized attention weights)")
print(omega)
# Out:
# Omega shape (4, 4)
# Omega (Unnormalized attention weights)
# tf.Tensor(
# [[ 1.1146356e-04  8.1373053e-04  1.2739128e-04 -3.9768935e-04]
#  [ 4.8979977e-04  1.5359244e-03  2.7240562e-04 -7.4982736e-04]
#  [ 8.1753526e-05  3.0945023e-04  5.2946925e-05 -1.5112080e-04]
#  [-2.3924727e-04 -7.4888230e-04 -1.3286827e-04  3.6559775e-04]], shape=(4, 4), dtype=float32)

# %%
d_k = tf.cast(d_k, tf.float32)

scaled_omega = omega / tf.sqrt(d_k)

attention_weights = tf.nn.softmax(scaled_omega, axis=-1)

print("Attention Weights")
print(attention_weights)
# Out:
# Attention Weights
# tf.Tensor(
# [[0.24999075 0.25011492 0.24999355 0.24990076]
#  [0.25001812 0.25020313 0.24997969 0.24979906]
#  [0.2500015  0.25004175 0.24999641 0.24996033]
#  [0.24999109 0.24990101 0.2500099  0.25009802]], shape=(4, 4), dtype=float32)

# %%
row_sums = tf.reduce_sum(attention_weights, axis=-1)

print("Sum of each row in attention_weights")
row_sums
# Out:
# Sum of each row in attention_weights
# <tf.Tensor: shape=(4,), dtype=float32, numpy=array([1., 1., 1., 1.], dtype=float32)>

# %%
context_vector = tf.matmul(attention_weights, values)

print("Context Vector shape", context_vector.shape)
print(context_vector)
# Out:
# Context Vector shape (4, 4)
# tf.Tensor(
# [[0.01139904 0.00941236 0.00856141 0.00953665]
#  [0.01140558 0.00941562 0.00856636 0.00953923]
#  [0.01139457 0.00941059 0.00855803 0.00953551]
#  [0.01138509 0.00940633 0.00855084 0.0095324 ]], shape=(4, 4), dtype=float32)

# %%
class SelfAttention(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v):
        super().__init__()
        self.d_out_kq = d_out_kq

        self.W_query = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_key = tf.Variable(
            tf.random.uniform((d_in, d_out_kq)), trainable=True
        )
        self.W_value = tf.Variable(
            tf.random.uniform((d_in, d_out_v)), trainable=True
        )

    def call(self, x):
        keys = tf.matmul(x, self.W_key)      # [T, d_out_kq]
        queries = tf.matmul(x, self.W_query) # [T, d_out_kq]
        values = tf.matmul(x, self.W_value)  # [T, d_out_v]

        # Attention scores: QKᵀ
        attn_scores = tf.matmul(queries, keys, transpose_b=True)  # [T, T]

        # Softmax (scaled by sqrt(d_k))
        attn_weights = tf.nn.softmax(
            attn_scores / tf.math.sqrt(tf.cast(self.d_out_kq, tf.float32)), axis=-1
        )  # [T, T]

        # Weighted sum
        context_vec = tf.matmul(attn_weights, values)  # [T, d_out_v]
        return context_vec

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 4

sa = SelfAttention(d_in, d_out_kq, d_out_v)

out = sa(embedded_sentence)

print(out.shape)  # (T, d_out_v)
print(out.numpy())
# Out:
# (4, 4)
# [[0.01139904 0.00941236 0.00856141 0.00953665]
#  [0.01140558 0.00941562 0.00856636 0.00953923]
#  [0.01139457 0.00941059 0.00855803 0.00953551]
#  [0.01138509 0.00940633 0.00855084 0.0095324 ]]

# %%
class MultiHeadAttentionWrapper(tf.keras.layers.Layer):
    def __init__(self, d_in, d_out_kq, d_out_v, num_heads):
        super().__init__()
        self.heads = [
            SelfAttention(d_in, d_out_kq, d_out_v)
            for _ in range(num_heads)
        ]

    def call(self, x):
        # รันทุก head แล้ว concat ตามแกนสุดท้าย
        head_outputs = [head(x) for head in self.heads]   # list of [T, d_out_v]
        return tf.concat(head_outputs, axis=-1)           # [T, num_heads * d_out_v]

# %%
tf.random.set_seed(123)

d_in, d_out_kq, d_out_v = 2, 2, 1

sa = SelfAttention(d_in, d_out_kq, d_out_v)

# ถ้า embedded_sentence.shape = [T, d_in] เช่น [6, 3]
out = sa(embedded_sentence)

print(out.shape)   # (T, d_out_v) -> (6, 1)
print(out.numpy())
# Out:
# (4, 1)
# [[0.00948483]
#  [0.0094893 ]
#  [0.00948199]
#  [0.00947571]]

# %%
tf.random.set_seed(123)

mha = MultiHeadAttentionWrapper(
    d_in, d_out_kq, d_out_v, num_heads=3
)

# run MHA
context_vecs = mha(embedded_sentence)   # [T, num_heads * d_out_v]

print(context_vecs)
print("context_vecs.shape:", context_vecs.shape)
# Out:
# tf.Tensor(
# [[0.00948483 0.01094013 0.01450029]
#  [0.0094893  0.0109406  0.01449064]
#  [0.00948199 0.01093773 0.01448843]
#  [0.00947571 0.01093497 0.01448405]], shape=(4, 3), dtype=float32)
# context_vecs.shape: (4, 3)
